# %%
from IPython.display import IFrame

# %%
def my_func():
    pass

def my_fun():
    
#pass는 할 말 없으니까 지나가란 소리! 비워두면 에러날 때그냥 지나가라고 추가하는거

# %% [markdown]
# ![image.png](attachment:image.png)
# 클래스도 선언된 후에는 오브젝트다. 우리가 이름줘서 만든 건 모두다 오브젝트다

# %% [markdown]
# # OOP with Python
#
# ## 용어 정리
#
# ```python
# class Person:                      #=> 클래스 정의(선언) : 클래스 객체 생성
#     name = '홍길동'                  #=> 멤버 변수(데이터 어트리뷰트)
#     def greeting(self):            #=> 멤버 메서드(메서드)
#         print(f'{self.name}')
# ```
#
#
# ```python
# iu = Person()       # 인스턴스 객체 생성
# daniel = Person()   # 인스턴스 객체 생성
# iu.name             # 데이터 어트리뷰트 호출
# iu.greeting()       # 메서드 호출
# ```

# %%
# Person을 만들어봅시다.
class Person:
    name = 'ssafy kim'
    def greeting(self):  #no self, then error
        return f'hi {self.name}'

p=Person()

print(p.name)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# 객체만의 독립적인 속성이 있어야지만 별도로 표시된다. 그 전에는 Person instance만 있다.

# %% [markdown]
# * 클래스와 인스턴스간의 관계를 확인해봅시다.

# %%
isinstance(1, int)
isinstance(p, Person) #p소문자면 에러난다

# %% [markdown]
# ##  `self` : 인스턴스 객체 자기자신
#
# * C++ 혹은 자바에서의 this 키워드와 동일함.
#
# * 특별한 상황을 제외하고는 무조건 메서드에서 `self`를 첫번째 인자로 설정한다.
#
# * 메서드는 인스턴스 객체가 함수의 첫번째 인자로 전달되도록 되어있다.

# %%
# p를 다시 인사시켜봅시다.
p.name='kim ssafy'
# print(p.greeting())
p.greeting()

# %%
# 다르게 인사를 시킬 수도 있습니다.
Person.greeting(p)
#사람이 인사를 합니다. 그런데 그 사람이 피입니다.

# %%
Person.greeting() #요건앙대

# %% [markdown]
# * 클래스 선언부 내부에서도 반드시 self를 통해 데이터 어트리뷰트에 접근 해야 합니다.

# %%
# 예시를 봅시다.
name= '?'
class Person:
    name = '아이돌'
    
    def greeting(self):
        print(f'hi my name is {self.name}')

# %%
p1 = Person()
print(p1.name)
p1.greeting()

# %%
name= '?'
class Person:
    name = '아기'
    
    def greeting(self):
        print(f'hi my name is {name}')

# %%
p1 = Person()
print(p1.name)
p1.greeting()

# %% [markdown]
# ## 클래스-인스턴스간의 이름공간
#
# * 클래스를 정의하면, 클래스 객체가 생성되고 해당되는 이름 공간이 생성된다.
#
# * 인스턴스를 만들게 되면, 인스턴스 객체가 생성되고 해당되는 이름 공간이 생성된다.
#
# * 인스턴스의 어트리뷰트가 변경되면, 변경된 데이터를 인스턴스 객체 이름 공간에 저장한다.
#
# * 즉, 인스턴스에서 특정한 어트리뷰트에 접근하게 되면 인스턴스 -> 클래스 순으로 탐색을 한다.

# %%
# p1에게 이름을 지정해줍시다.
p1.name='John'
p1.name

# %%
# 아래의 Python Tutor를 통해 순차적으로 확인해봅시다.
IFrame('https://goo.gl/ZgNaXB', width='100%', height='300px')

# %% [markdown]
# ## 생성자 / 소멸자
#
# * 생성자는 인스턴스 객체가 생성될 때 호출되는 함수이며, 소멸자는 객체가 소멸되는 과정에서 호출되는 함수입니다.
#
# ```python
# def __init__(self):
#     print('생성될 때 자동으로 호출되는 메서드입니다.')
#
# def __del__(self):
#     print('소멸될 때 자동으로 호출되는 메서드입니다.')
# ```
#
# ```
# __someting__
# ```
#
# 위의 형식처럼 양쪽에 언더스코어가 있는 메서드를 스페셜 메서드 혹은 매직 메서드라고 불립니다.

# %%
# 생성자와 소멸자를 만들어봅시다. 얘네가 함수라는 게 중요!
class Person:
    def __init__(self):
        print ('응애')

    def __del__(self):
        print ('빠잉!')

# %%
#  생성시켜봅시다.
p1 = Person()

# %%
# 소멸시켜봅시다.
del p1

# %%
p1 = 1 #덮어씌워져서 원래의 PErson 객체는 사라진다.

# %% [markdown]
# 진짜 지운 것은 아니더라도 정보가 있는 공간을 가리키는 게 없으면, 소유권을 주장하는 프로그램이나 변수가 없어지면 바로 다른 것으로 덮어씌울 수 있다. 그것을 삭제라고 하기 때문에 설치는 느려도 삭제는 빠른 이유다.

# %% [markdown]
# * 생성자 역시 메소드이기 때문에 추가적인 인자를 받을 수 있습니다.

# %%
# 생성자에서 이름을 추가적으로 받아서 출력해봅시다.
class Person:
    def __init__(self, name):
        self.name=name
        print ('응애')

    def __del__(self):
        print ('빠잉!')

# %%
# 홍길동이라는 이름을 가진 hong 을 만들어봅시다.
hong=Person('홍길동')
print(hong.name)
hong=Person('홍삼')
print(hong.name)

# %% [markdown]
# 커널 날리고 처음 위를 실행하면 응애 홍길동인데, 두 번째부터는 응애빠잉 홍길동입니다. 그 이유는 원래 있던 hong 객체 위를 다른 것으로 덮어씌우면서 기존의 hong은 삭제되기 때문이다.

# %% [markdown]
# * 아래와 같이 모두 사용할 수 있습니다!
#
# ```python
# def __init__(self, parameter1, parameter2):
#     print('생성될 때 자동으로 호출되는 메서드입니다.')
#     print(parameter1)
#
# def __init__(self, *args):
#     print('생성될 때 자동으로 호출되는 메서드입니다.')
#
# def __init__(self, **kwagrs):
#     print('생성될 때 자동으로 호출되는 메서드입니다.')
# ```

# %% [markdown]
# * 따라서, 생성자는 값을 초기화하는 과정에서 자주 활용됩니다.
#
# * 아래의 클래스 변수와 인스턴스 변수를 통해 확인해보겠습니다.

# %% [markdown]
# ## 클래스 변수 / 인스턴스 변수
#
# ```python
# class Person:
#     population = 0              # 클래스 변수 : 모든 인스턴스가 공유함.
#
#     def __init__(self, name):
#         self.name = name        # 인스턴스 변수 : 인스턴스별로 각각 가지는 변수
# ```

# %%
a=1
def upper_func():
    def func():
        # a += 1
        return a
    return func()
    
print(upper_func())

# %% [markdown]
# 위 함수에서 a+=1을 살리면 에러가 난다. 그 이유는 함수 밖 변수를 오직 참조할 수만 있을 뿐, 함수 내에서 수정하는 것은 불가하기 때문이다. 아래 함수에서도 population 앞에서 Person 지우면 실행 시 에러난다.

# %%
# 위의 생성자와 인사하는 메소드를 만들어봅시다. 
class Person:
    population = 0
    def __init__(self, name):
        self.name = name
        Person.population += 1  

#클래스 내 메소드는 클래스공간에서 정의된 변수를 사용하기 위해 클래스명(즉, 변수의 위치)을 명시해줘야 한다.

# %%
# 본인의 이름을 가진 인스턴스를 만들어봅시다.
baik = Person('Jiwon')

# %%
# 이름을 출력해봅시다.
baik.name

# %%
# 옆자리 친구의 이름을 가진 인스턴스를 만들어봅시다.
kang= Person('Jinwoo')

# %%
# 이름을 출력해봅시다.
kang.name

# %%
# population을 출력해봅시다.
print(Person.population)

# %%
# 물론, 인스턴스도 접근 가능합니다. 왜일까요?! 얻어걸린겁니다. 이름공간 넓혀가면서 보다 보니 찾아서 그냥 말해주는 것.
baik.population

# %% [markdown]
# ## 정적 메서드 / 클래스 메서드
#
# * 메서드 호출을 인스턴스가 아닌 클래스가 할 수 있도록 구성할 수 있습니다.
#
# * 이때 활용되는게 정적 메서드 혹은 클래스 메서드입니다.
#
# * 정적 메소드는 객체가 전달되지 않은 형태이며, 클래스 메서드는 인자로 클래스를 넘겨준다.

# %%
# Person 클래스가 인사할 수 있는지 확인해보겠습니다.
class Person:
    population = 0
    def __init__(self, name):
        self.name = name
        Person.population += 1
    def greeting(self, name):
        print(f'hi my name is {self.name}')
    def show_population(): #객체 없이 진행되는 정적 메소드라 클래스가 주체여도 실행가능.
        print(f'오늘의 인구는 {Person.population}')

# Person.greeting() # 이건 안 됨! 괄호에 객체 넣어주면 됨.
p=Person('sov')
Person.show_population()

# %%
# 이번에는 Dog class를 만들어보겠습니다.
# 클래스 변수 num_of_dogs 통해 개가 생성될 때마다 증가시키도록 하겠습니다. 
# 개들은 각자의 이름과 나이를 가지고 있습니다. 
# 그리고 bark() 메서드를 통해 짖을 수 있습니다. 

class Dog:
    num_of_dogs = 0
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed
        Dog.num_of_dogs += 1
    def bark(self):
        return '왈왈'
    def __del__(self):
        Dog.num_of_dogs -= 1

# %%
# 각각 이름과 나이가 다른 인스턴스를 3개 만들어봅시다.
d1 = Dog('choco', '푸들')
d2 = Dog('꽁이', '말티즈')
d3 = Dog('별이', '시츄')
d1.bark()

# %% [markdown]
# * staticmethod는 다음과 같이 정의됩니다.
#
# ```python
#
# @staticmethod
# def methodname():
#     codeblock
# ```

# %%
# 단순한 static method를 만들어보겠습니다.
class Dog:
    num_of_dogs = 0
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed
        Dog.num_of_dogs += 1
    def bark(self):
        return '왈왈'
    def __del__(self):
        Dog.num_of_dogs -= 1
    @staticmethod
    def info():
        return f'총 {Dog.num_of_dogs}마리의 개가 있습니다'

# %%
# 3마리를 만들어보고,
d1 = Dog('choco', '푸들')
d2 = Dog('꽁이', '말티즈')
d3 = Dog('별이', '시츄')

# %%
# 함수를 호출해봅시다.
Dog.info()

# %% [markdown]
# * classmethod는 다음과 같이 정의됩니다.
#
# ```python
#
# @classmethod
# def methodname(cls):
#     codeblock
# ```

# %%
# 개의 숫자를 출력하는 classmethod를 만들어보겠습니다.
class Dog:
    num_of_dogs = 0
    birth_of_dogs = 0
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed
        Dog.num_of_dogs += 1
        Dog.birth_of_dogs += 1
    def bark(self):
        return '왈왈'
    def __del__(self):
        Dog.num_of_dogs -= 1
    @staticmethod
    def info():
        return f'총 {Dog.num_of_dogs}마리의 개가 있습니다'
    @classmethod
    def birth(cls):
        return f'총 {cls.birth_of_dogs}마리의 개가 태어났습니다!'

# %%
# 3마리를 만들어보고,
d1 = Dog('choco', '푸들')
d2 = Dog('꽁이', '말티즈')
d3 = Dog('별이', '시츄')

# %%
# 함수를 호출해봅시다.
print(Dog.info())
print(Dog.birth())
# Out:
# 총 3마리의 개가 있습니다
# 총 3마리의 개가 태어났습니다!

# %%
class Dog:
    num_of_dogs = 0
    birth_of_dogs = 0
    list_of_dogs = []
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed
        Dog.num_of_dogs += 1
        Dog.birth_of_dogs += 1
        Dog.list_of_dogs.append(self.name)
    def bark(self):
        return '왈왈'
    def __del__(self):
        Dog.num_of_dogs -= 1
    @staticmethod
    def info():
        return '개입니다'
    @classmethod
    def birth(cls):
        return f'총 {cls.birth_of_dogs}마리의 개가 태어났습니다!\n현재 {cls.num_of_dogs}마리가 있습니다'
    
d = Dog('choco', 'poodle')
print(d.bark())
print(d.info(), Dog.info())
print(Dog.birth())
# Out:
# 왈왈
# 개입니다 개입니다
# 총 1마리의 개가 태어났습니다!
# 현재 1마리가 있습니다

# %% [markdown]
# 스태틱은 클래스 오브젝트 안 따지기 때문에 이런 특성에 맞는 함수
#
# 클래스 메소드는 오브젝트는 접근할 수 없는 클래스 전체에 맞는 함수를 정의한다.
#
# 정적 혹은 클래스 메소드가 아니면 모두 인스턴스 메소드다
#
#
# 정적 메소드에는 따라서 데이터를 조작하는 메소드는 넣지 않는 것이 좋다. 조회하는 함수를 넣으면 유용하게 사용할 수 있다.

# %% [markdown]
# ## 실습문제 - 정적 메소드
#
# > 계산기 class인 `Calculator`를 만들어봅시다.
#
# * 정적 메소드 : 두 수를 받아서 각각의 연산을 한 결과를 반환(return)
#
#     1. `add()` : 덧셈
#
#     2. `sub()` : 뺄셈
#
#     3. `mul()` : 곱셈
#
#     4. `div()` : 나눗셈

# %%
# 아래에 코드를 작성해주세요.
class Calculator:
    @staticmethod
    def add(a, b):
        return a + b
    @staticmethod
    def sub(a, b):
        return a - b
    @staticmethod
    def mul(a, b):
        return a * b
    @staticmethod
    def div(a, b):
        return a / b

# %%
# 정적메소드를 호출해보세요.
print(Calculator.add(1,2))
print(Calculator.sub(1,2))
print(Calculator.mul(1,2))
print(Calculator.div(1,2))
# Out:
# 3
# -1
# 2
# 0.5

# %% [markdown]
# ## 실습문제 - 종합1
#
# > 사실 이전에 작성한 Mylist는 완벽하지 않았습니다.
# >
# > 한번 제대로 된 자료구조를 만들어보겠습니다.
# >
# > `Stack` 클래스를 간략하게 구현해봅시다.
#
# > [Stack](https://ko.wikipedia.org/wiki/%EC%8A%A4%ED%83%9D) : 스택은 LIFO(Last in First Out)으로 구조화된 자료구조를 뜻합니다.
#
# 1. `empty()`: 스택이 비었다면 참을 주고,그렇지 않다면 거짓이 된다.
#
# 2. `top()`: 스택의 가장 마지막 데이터를 넘겨준다. 스택이 비었다면 None을 리턴해주세요.
#
# 3. `pop()`: 스택의 가장 마지막 데이터의 값을 넘겨주고 해당 데이터를 삭제한다. 스택이 비었다면 None을 리턴해주세요.
#
# 4. `push()`: 스택의 가장 마지막 데이터 뒤에 값을 추가한다. 리턴값 없음
#
# **다 완료하신 분들은 __repr__을 통해 예쁘게 출력까지 해봅시다.**

# %%
# 여기에 코드를 작성해주세요.
class Stack:
    def __init__(self):
        self.items = []
    def empty(self):
        #return False if self.items else True
        #reture not bool(self.items)
        if self.items == []:
            return True
        return False
    def top(self):
        if self.empty():
            return None
        return self.items[-1]
    def pop(self):
        if self.empty():
            return None
        return self.items.pop()
    def push(self, a):
        self.items.append(a)
  
     # 객체 자체가 리턴하는 값
    def __repr__(self):
        k = reversed(self.items)
        return '\n'.join(map(str, k))
    
    # 객체를 print 하면 나오는 값
#     def __str__(self):
#         return '|'.join(map(str, self.items))

#     #객체 자체가 리턴하는 값
#     def __repr__(self):
#         return "\n".join(self.items)  #그냥 각 인스턴스를 찍었을 때 디퐅트는 주소값이지만, 그게 아니라 뭐가 나오면 좋을지를 정할 수 있다.
#     #객체를 프린트하면 나오는 값.
#     def __str__(self):
#         return '|'.join(self.items)  #print(인스턴스)했을 때 뭐 줄지.

# %%
s = Stack()
s.push('a')
s.push('2')
s
print(s)
# Out:
# 2
# a

# %%
class Stack:
    def __init__(self):
        self.items = []
    
    def empty(self):
        return not bool(self.items)
    
    def push(self, e):
        self.items.append(e)
        
    def pop(self):
        if not self.empty():
            return self.items.pop()
        
    def top(self):
        if self.items:
            return self.items[-1]
    
    # 객체 자체가 리턴하는 값
    def __repr__(self):
        return '\n'.join(str(self.items))
    
    # 객체를 print 하면 나오는 값
    def __str__(self):
        return '|'.join(str(self.items))

# %%
s = Stack()
s.empty() # True
s.push(1) # None
s.push(2) # None
s.empty() # False
s.top()   # 2
s.empty() # False
s.pop()   # 2
s.empty() # False
s.top()   # 1
s.pop()   # 1
s.pop()   # None
s.empty() # True
s.push('a')
s.push('b')
s.push('c')
print(s)

# %%
# 인스턴스를 하나 만들고 메소드 조작을 해봅시다.
l = Stack()
# print(type(l.items)) #list
# print(l.empty())
# print(l.push(1))
# print(l.push(2))
# print(l.empty())
# print(l.top())
# print(l.empty())
# print(l.pop())
# print(l.empty())
# print(l.top())
# print(l.pop())
# print(l.pop())
# print(l.empty())
l.push('a')
l.push('b')
l
print(l)

# %% [markdown]
# ## 연산자 오버라이딩(중복 정의)
#
# * 파이썬에 기본적으로 정의된 연산자를 직접적으로 정의하여 활용할 수 있습니다.
#
# * 몇가지만 소개하고 활용해봅시다.
#
# ```
# +  __add__
# -  __sub__
# *  __mul__
# <  __lt__
# <= __le__
# == __eq__
# != __ne__
# >= __ge__
# >  __gt__
# ```

# %%
# 사람과 사람을 같은지 비교하면, 이는 나이가 같은지 비교한 결과를 반환하도록 만들어봅시다.
class Person:
    population = 0
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.population += 1
        
    def greeting(self):
        print(f'{self.name}입니다. 반갑습니다.')
        
    def __repr__(self):
        return f" < 'name:' {self.name}, 'age': {self.age} > "
    
    def __gt__(self, other):
        if self.age > other.age:
            return '왼쪽이 연장자'
        else:
            return '오른쪽이 연장자'
    def __add__(self, other):
            return  '얌마 못더함!'

# %%
p1 = Person('유태영', 100)
p1
p2 = Person('손흥민', 28)

p1 > p2

# 연산자를 호출해봅시다.
# Out:
# '왼쪽이 연장자'

# %%
(1).__add__(2)
(3).__gt__(2)
# Out:
# True

# %%
# 원하는 연산자를 사람과 사람을 비교해보세요.

# %%
# 파이썬 내부를 살펴봅시다.

# %% [markdown]
# # 상속
#
# ## 기초
#
# * 클래스에서 가장 큰 특징은 '상속' 기능을 가지고 있다는 것이다.
#
# * 부모 클래스의 모든 속성이 자식 클래스에게 상속 되므로 코드재사용성이 높아집니다.
#
# ```python
# class DerivedClassName(BaseClassName):
#     code block
# ```

# %%
# 인사만 할 수 있는 간단한 사람 클래스를 만들어봅시다.
class Person:
    population = 0
    def __init__(self, name='사람'):
        self.name = name
        Person.population += 1
    def greeting(self):
        print(f'반갑습니다. {self.name}입니다')

p = Person()
p.greeting()
# Out:
# 반갑습니다. 사람입니다

# %%
# 사람 클래스를 상속받아 학생 클래스를 만들어봅시다.
class Student(Person):
    def __init__(self, student_id, name='학생'): #오버라이드!
        self.name = name
        self.student_id = student_id
        Person.population += 1
    def greeting(self):
        print(f'반갑습니다., {self.student_id}번 학생 {self.name}입니다')

# %%
# 학생을 만들어봅시다.
s = Student(1)
# 부모 클래스에 정의를 했음에도 메소드를 호출 할 수 있습니다.
s.greeting()
s.population
# Out:
# 반갑습니다., 1번 학생 학생입니다
# 2

# %% [markdown]
# * 이처럼 상속은 공통된 속성이나 메소드를 부모 클래스에 정의하고, 이를 상속받아 다양한 형태의 사람들을 만들 수 있습니다.

# %%
# 진짜 상속관계인지 확인해봅시다.
issubclass(Person, Student)
# Out:
# False

# %%
issubclass(Student, Person)
# Out:
# True

# %%
isinstance(s, Student)
# Out:
# True

# %%
isinstance(s, Person)
# Out:
# True

# %% [markdown]
# ## super()
#
# * 자식 클래스에 메서드를 추가 구현할 수 있습니다.
#
# * 부모 클래스의 내용을 사용하고자 할 때, `super()`를 사용할 수 있습니다.

# %%
class Person:
    def __init__(self, name, age, number, email):
        self.name = name
        self.age = age
        self.number = number
        self.email = email 

    def greeting(self):
        print(f'안녕, {self.name}')

class Student(Person):
    def __init__(self, name, age, number, email, student_id):
        self.name = name
        self.age = age
        self.number = number
        self.email = email 
        self.student_id = student_id

p1 = Person('홍길동', 200, '0101231234', 'hong@gildong')
s1 = Student('학생', 20, '12312312', 'student@naver.com', '190000')

# %% [markdown]
# * 위의 코드를 보면, 상속을 했음에도 불구하고 동일한 코드가 반복됩니다.

# %%
# 이를 수정해봅시다.
class Person:
    def __init__(self, name, age, number, email):
        self.name = name
        self.age = age
        self.number = number
        self.email = email 

    def greeting(self):
        print(f'안녕, {self.name}')

class Student(Person):
    def __init__(self, name, age, number, email, student_id):
        super().__init__(name, age, number, email) #상위클래스 내용을 가져오기
        self.student_id = student_id

p1 = Person('홍길동', 200, '0101231234', 'hong@gildong')
s1 = Student('학생', 20, '12312312', 'student@naver.com', '190000')
s1.greeting()
# Out:
# 안녕, 학생

# %% [markdown]
# ## 메소드 오버라이딩
#
# * 메서드를 재정의할 수도 있습니다.

# %%
# 군인은 다른 인사를 합니다.
class Soldier(Person):
    def __init__(self, name, age, number, email, army):
        super().__init__(name, age, number, email)
        self.army= army

    def greeting(self):
        print(f'충성! {self.army} {self.name}')
        
s = Soldier('권택건', 25, '01012345678', 'Hermes@hermes.com', '준위')
s.greeting()
# Out:
# 충성! 준위 권택건

# %% [markdown]
# ## 상속관계에서의 이름공간
#
# * 기존에 인스턴스 -> 클래스순으로 이름 공간을 탐색해나가는 과정에서 상속관계에 있으면 아래와 같이 확장됩니다.
#
# * 인스턴스 -> 자식 클래스 -> 부모 클래스 -> 전역

# %% [markdown]
# ## 실습1
#
# > Teacher 클래스를 만들어보고 Student와 Teacher 클래스에 각각 다른 행동의 메소드들을 하나씩 추가해봅시다.

# %%
# 아래에 코드를 작성해주세요.
class Teacher:
    def __init__(self, name):
        self.name = name
    def greeting(self):
        print (f'안녕 {self.name}선생님이야')
        
class Student:
    def __init__(self, name):
        self.name = name
    def study(self):
        print(f'{self.name}은/는 열심히 공부를 해요')

# %%
t = Teacher('yu')
s = Student('baik')

t.greeting()
s.study()
# Out:
# 안녕 yu선생님이야
# baik은/는 열심히 공부를 해요

# %% [markdown]
# ## 실습2
#
# > 사실 사람은 포유류입니다.
# >
# > Animal Class를 만들고, Person클래스가 상속받도록 구성해봅시다.
# >
# > 변수나, 메소드는 자유롭게 만들어봅시다.

# %%
# 아래에 코드를 작성해주세요.

class Animal:
    age = 0
    d = 100
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def eat(self, food):
        Animal.d -= 30
        print(f'{self.name}은 {food}를 먹는다. d={self.d}')
    def bark(self):
        print('bark!')
        
class Person(Animal):
    def __init__(self, name, age, friend):
        super().__init__(name, age)
        self.friend = friend
    def bark(self):
        print('talk!')

        
choco = Animal('choco', 3)
jiwon = Person('jiwon', 24, 'joo')

jiwon.eat('치킨')
jiwon.bark()
# Out:
# jiwon은 치킨를 먹는다. d=70
# talk!

# %%
class Person:
    def __init__(self, name):
        self.name = name
    def breath(self):
        return '날숨'
    def greeting(self):
        return 'hi' + self.name

class Mom(Person):
    gene = 'XX'
    def swim(self):
        return '첨벙첨벙'
    
class Dad(Person):
    gene = 'XY'
    
    def kick(self):
        return '슛'
    
class Child( Mom, Dad ):
    def cry(self):
        return '응애'

c = Child('애')
c.swim()
c.kick()
c.gene #'XX' Mom의 클래스가 맨 앞에 있어서. 
c.cry()
# Out:
# '응애'
